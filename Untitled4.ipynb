# %% [markdown]
# <a href="https://colab.research.google.com/github/ebro033/dz/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sqlalchemy import create_engine
import sqlite3
import os

# %%
current_directory = os.getcwd()
print(current_directory)
# Out:
# /content

# %%
#dataframe


from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0d27d2c4-d754-4665-961c-c892460a0523" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0d27d2c4-d754-4665-961c-c892460a0523">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-08c29e9f-b2ce-49c3-a111-8955f2122a43" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-08c29e9f-b2ce-49c3-a111-8955f2122a43">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f4c4ac77-104b-4a40-a46f-d689c60c29ef" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f4c4ac77-104b-4a40-a46f-d689c60c29ef">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df1 = pd.read_excel('area.xlsx', engine='openpyxl')
df2 = pd.read_excel('employer.xlsx', engine='openpyxl')
df3 = pd.read_excel('vacancies_data_for_analysis-1.xlsx', engine='openpyxl')

# %%
dataframes = [df1, df2, df3]

for i, df in enumerate(dataframes):
    # Удаление дубликатов строк
    df.drop_duplicates(inplace=True)

    # Удаление строк с пустыми значениями
    df.dropna(inplace=True)

    dataframes[i] = df

df1, df2, df3 = dataframes

# %%
#очистка от лишних столбцов
columns_to_keep = ['id', 'name', 'area.id', 'address.metro.station_name',
                   'salary.from', 'salary.to', 'address.raw', 'experience.name',
                   'schedule.name', 'employment.name', 'employer.id',
                   'alternate_url', 'created_at']


df3 = df3[columns_to_keep]

# %%
com_df = com_df.drop_duplicates()

# %%
# !pip install sqlalchemy

# %%
# Создаем датафреймы для примера
df1 = pd.DataFrame({
    'A': ['A0', 'A1', 'A2', 'A3'],
    'B': ['B0', 'B1', 'B2', 'B3'],
    'C': ['C0', 'C1', 'C2', 'C3'],
    'D': ['D0', 'D1', 'D2', 'D3'],
})

df2 = pd.DataFrame({
    'A': ['A4', 'A5', 'A6', 'A7'],
    'B': ['B4', 'B5', 'B6', 'B7'],
    'C': ['C4', 'C5', 'C6', 'C7'],
    'D': ['D4', 'D5', 'D6', 'D7'],
})

df3 = pd.DataFrame({
    'A': ['A8', 'A9', 'A10', 'A11'],
    'B': ['B8', 'B9', 'B10', 'B11'],
    'C': ['C8', 'C9', 'C10', 'C11'],
    'D': ['D8', 'D9', 'D10', 'D11'],
})

# Создайте новую базу данных (если файл не существует, он будет создан)
conn = sqlite3.connect('new_database.db')

# Загрузите датафреймы в базу данных SQLite
df1.to_sql('Table1', conn, if_exists='replace', index=False)
df2.to_sql('Table2', conn, if_exists='replace', index=False)
df3.to_sql('Table3', conn, if_exists='replace', index=False)

# Закройте соединение
conn.close()

from google.colab import files

files.download('new_database.db')
